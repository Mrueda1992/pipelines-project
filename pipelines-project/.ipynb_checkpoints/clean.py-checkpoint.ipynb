# %%
import pandas as pd
import matplotlib
import seaborn as sns

# %%
read_csv = pd.read_csv('nba-stats.csv')
data = pd.DataFrame(read_csv)
data.head()
data.shape
data.columns
#data.isnull().sum()
# Out:
# Index(['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2',
#        'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
#solo queremos estadísticas de tiro para medir a los mejores tiradores de triples
df = pd.DataFrame()
df = data[['Year','Player','Pos','Age','Tm','PER','3PAr','3P', '3PA', '3P%',
       '2P', '2PA', '2P%', 'eFG%','PTS']]
#limpiamos nulos
df.fillna("0").head()
# Out:
#    Year           Player  Pos Age   Tm PER 3PAr 3P 3PA 3P%   2P  2PA    2P%  \
# 0  1950  Curly Armstrong  G-F  31  FTW   0    0  0   0   0  144  516  0.279
# 1  1950     Cliff Barker   SG  29  INO   0    0  0   0   0  102  274  0.372
# 2  1950    Leo Barnhorst   SF  25  CHS   0    0  0   0   0  174  499  0.349
# 3  1950       Ed Bartels    F  24  TOT   0    0  0   0   0   22   86  0.256
# 4  1950       Ed Bartels    F  24  DNN   0    0  0   0   0   21   82  0.256
#
#     eFG%  PTS
# 0  0.279  458
# 1  0.372  279
# 2  0.349  438
# 3  0.256   63
# 4  0.256   59

# %%
df.rename(index=str, columns= {"Pos":"Position","Tm":"Team"}).head(1)
# Out:
#      Year           Player Position   Age Team  PER  3PAr  3P  3PA  3P%  \
# 0  1950.0  Curly Armstrong      G-F  31.0  FTW  NaN   NaN NaN  NaN  NaN
#
#       2P    2PA    2P%   eFG%    PTS
# 0  144.0  516.0  0.279  0.279  458.0

# %%
#filtramos por años superiores a 1980
over_2009 = df['Year']>=2009
nba= df[over_2009]
nba.head(100)
# Out:
#          Year             Player    Pos   Age   Tm   PER   3PAr     3P    3PA  \
# 19339  2009.0         Alex Acker     SG  26.0  TOT  10.4  0.263    7.0   20.0
# 19340  2009.0         Alex Acker     SG  26.0  DET  16.0  0.364    0.0    4.0
# 19341  2009.0         Alex Acker     SG  26.0  LAC   9.8  0.246    7.0   16.0
# 19342  2009.0       Hassan Adams     SG  24.0  TOR   0.4  0.000    0.0    0.0
# 19343  2009.0      Arron Afflalo     SG  23.0  DET   8.9  0.357   43.0  107.0
# 19344  2009.0       Maurice Ager     SG  24.0  NJN   2.2  0.140    0.0    6.0
# 19345  2009.0       Blake Ahearn     PG  24.0  SAS  12.9  0.667    2.0    4.0
# 19346  2009.0      Alexis Ajinca     PF  20.0  CHA   7.0  0.029    0.0    2.0
# 19347  2009.0  LaMarcus Aldridge     PF  23.0  POR  19.1  0.023    7.0   28.0
# 19348  2009.0      Joe Alexander     SF  22.0  MIL  10.1  0.188   16.0   46.0
# 19349  2009.0        Malik Allen     PF  30.0  MIL   7.3  0.006    0.0    1.0
# ...

# %%
#máximo anotador de triples desde 2009

three_pts = [nba.groupby('Player')['3P'].sum().sort_values(ascending=False)]

# %%
#mayores tiradores de triples desde 2009
MostThrees = pd.DataFrame()
MostThrees['Player']= nba['Player'].unique()
# Out:
#           Player
# 0     Alex Acker
# 1   Hassan Adams
# 2  Arron Afflalo
# 3   Maurice Ager
# 4   Blake Ahearn

# %%
defT
# Out:
#                    Player  3PTLeaders
# 0              Alex Acker    178843.0
# 1            Hassan Adams    178843.0
# 2           Arron Afflalo    178843.0
# 3            Maurice Ager    178843.0
# 4            Blake Ahearn    178843.0
# 5           Alexis Ajinca    178843.0
# 6       LaMarcus Aldridge    178843.0
# 7           Joe Alexander    178843.0
# 8             Malik Allen    178843.0
# 9               Ray Allen    178843.0
# 10             Tony Allen    178843.0
# 11          Morris Almond    178843.0
# 12           Rafer Alston    178843.0
# 13           Lou Amundson    178843.0
# 14         Chris Andersen    178843.0
# 15          Ryan Anderson    178843.0
# 16        Carmelo Anthony    178843.0
# 17           Joel Anthony    178843.0
# 18         Gilbert Arenas    178843.0
# 19           Trevor Ariza    178843.0
# 20       Hilton Armstrong    178843.0
# 21         Darrell Arthur    178843.0
# 22          Chucky Atkins    178843.0
# 23          D.J. Augustin    178843.0
# ...

# %%
def MostThrees(y):
    for

# %%
#porcentaje de acierto de 3pts
three_leaders = pd.DataFrame()
three_leaders['Player']=nba2['Player']
three_leaders ['MostThrees'] = three_leaders.apply(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-a367323f376f> in <module>
#       2 three_leaders = pd.DataFrame()
#       3 three_leaders['Player']=nba2['Player']
# ----> 4 three_leaders ['MostThrees'] = three_leaders['Player'].apply(x)
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# TypeError: 'Series' object is not callable

# %%
three_leaders.head()
# Out:
#               Player
# 19339     Alex Acker
# 19340     Alex Acker
# 19341     Alex Acker
# 19342   Hassan Adams
# 19343  Arron Afflalo
